# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df_meta=pd.read_excel("/kaggle/input/prepostmenopausedepressionmetabolites/PrePostMenopauseDepressionMetabolites.xlsx","Subject Data", header=1, index_col=2)
df_meta=df_meta.drop(df_meta.columns[0], axis=1)
df_meta
# Out:
#                 Subject ID Sample Source      Condition     Symptom Batch
# Sample ID
# 20210111_MP_1            1        Plasma   Premenopause  Depression   B1A
# 20210111_MP_2            2        Plasma   Premenopause  Depression   B1A
# 20210111_MP_3            3        Plasma   Premenopause  Depression   B1A
# 20210111_MP_4            4        Plasma   Premenopause     Control   B1A
# 20210111_MP_5            5        Plasma   Premenopause  Depression   B1A
# ...                    ...           ...            ...         ...   ...
# 20210111_LC_145        145        Plasma  Postmenopause  Depression   B1A
# 20210111_LC_146        146        Plasma  Postmenopause  Depression   B1A
# 20210111_LC_147        147        Plasma  Postmenopause     Control   B1A
# 20210111_LC_148        148        Plasma  Postmenopause  Depression   B1A
# 20210111_LC_200        131        Plasma  Postmenopause  Depression   B1A
#
# [401 rows x 5 columns]

# %%
df=pd.read_excel("/kaggle/input/prepostmenopausedepressionmetabolites/PrePostMenopauseDepressionMetabolites.xlsx","MS Metabolite Data", header=1, index_col=1)
df=df.drop(df.columns[0], axis=1)
#df.replace('----', np.nan, inplace=True)
df.replace('----', 0, inplace=True)
df
# Out:
#                                                                    20210111_MP_1  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Premenopause ...
# Cystine                                                                     1130
# Asparagine                                                                 14176
# Aspartic acid                                                              13315
# Serine                                                                     69261
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                   20210111_MP_10  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Premenopause ...
# Cystine                                                                      352
# Asparagine                                                                 17063
# Aspartic acid                                                              14570
# Serine                                                                     81971
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                  20210111_MP_100  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                     4681
# Asparagine                                                                 22460
# Aspartic acid                                                              12596
# Serine                                                                    106370
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                  20210111_MP_101  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                     3135
# Asparagine                                                                 11320
# Aspartic acid                                                              29738
# Serine                                                                     95015
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                  20210111_MP_102  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                     2214
# Asparagine                                                                 24267
# Aspartic acid                                                              31347
# Serine                                                                    121294
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                  20210111_MP_103  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      730
# Asparagine                                                                 14292
# Aspartic acid                                                              13158
# Serine                                                                    107765
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                  20210111_MP_104  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                     1307
# Asparagine                                                                 16315
# Aspartic acid                                                              16731
# Serine                                                                     77045
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                  20210111_MP_106  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                     1130
# Asparagine                                                                 12861
# Aspartic acid                                                              17701
# Serine                                                                     64859
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                  20210111_MP_107  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                     2795
# Asparagine                                                                 26461
# Aspartic acid                                                              36471
# Serine                                                                    131452
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                                                  20210111_MP_108  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                     2251
# Asparagine                                                                 19395
# Aspartic acid                                                              26319
# Serine                                                                     97156
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                                 NaN
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                NaN
# SPH(d18:1/24:0)                                                              NaN
# Isovaleryl-L-Carnitine                                                       NaN
# 2-Ketoglutaric Acid                                                          NaN
#
#                                ...  \
# Sample ID                      ...
# Factors                        ...
# Cystine                        ...
# Asparagine                     ...
# Aspartic acid                  ...
# Serine                         ...
# ...                            ...
# PC(36:1) / PC(18:1(9Z)/18:0)   ...
# SM(d18:1/24:1(15Z)) / 24:1 SM  ...
# SPH(d18:1/24:0)                ...
# Isovaleryl-L-Carnitine         ...
# 2-Ketoglutaric Acid            ...
#
#                                                                    20210111_LC_9  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Premenopause ...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                            91321505
# SM(d18:1/24:1(15Z)) / 24:1 SM                                            2110013
# SPH(d18:1/24:0)                                                           635465
# Isovaleryl-L-Carnitine                                                         0
# 2-Ketoglutaric Acid                                                         3094
#
#                                                                   20210111_LC_90  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                           379262938
# SM(d18:1/24:1(15Z)) / 24:1 SM                                           62088219
# SPH(d18:1/24:0)                                                           370729
# Isovaleryl-L-Carnitine                                                    107550
# 2-Ketoglutaric Acid                                                         7697
#
#                                                                   20210111_LC_91  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                           287228637
# SM(d18:1/24:1(15Z)) / 24:1 SM                                           65877454
# SPH(d18:1/24:0)                                                          1462733
# Isovaleryl-L-Carnitine                                                     85729
# 2-Ketoglutaric Acid                                                         6105
#
#                                                                   20210111_LC_92  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                           122452581
# SM(d18:1/24:1(15Z)) / 24:1 SM                                            2497744
# SPH(d18:1/24:0)                                                           215563
# Isovaleryl-L-Carnitine                                                     27870
# 2-Ketoglutaric Acid                                                         3973
#
#                                                                   20210111_LC_93  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                           115790342
# SM(d18:1/24:1(15Z)) / 24:1 SM                                           36069344
# SPH(d18:1/24:0)                                                           313650
# Isovaleryl-L-Carnitine                                                     98667
# 2-Ketoglutaric Acid                                                         5619
#
#                                                                   20210111_LC_94  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                            94277208
# SM(d18:1/24:1(15Z)) / 24:1 SM                                                  0
# SPH(d18:1/24:0)                                                           257598
# Isovaleryl-L-Carnitine                                                     33594
# 2-Ketoglutaric Acid                                                         1994
#
#                                                                   20210111_LC_95  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                           207340705
# SM(d18:1/24:1(15Z)) / 24:1 SM                                           47663483
# SPH(d18:1/24:0)                                                          1403869
# Isovaleryl-L-Carnitine                                                     99391
# 2-Ketoglutaric Acid                                                         9149
#
#                                                                   20210111_LC_96  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                           359063863
# SM(d18:1/24:1(15Z)) / 24:1 SM                                           11724618
# SPH(d18:1/24:0)                                                           493608
# Isovaleryl-L-Carnitine                                                     86762
# 2-Ketoglutaric Acid                                                         4858
#
#                                                                   20210111_LC_97  \
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                            98032980
# SM(d18:1/24:1(15Z)) / 24:1 SM                                            1912578
# SPH(d18:1/24:0)                                                            71959
# Isovaleryl-L-Carnitine                                                     54580
# 2-Ketoglutaric Acid                                                         4134
#
#                                                                   20210111_LC_99
# Sample ID
# Factors                        Sample source:Plasma | Condition:Postmenopause...
# Cystine                                                                      NaN
# Asparagine                                                                   NaN
# Aspartic acid                                                                NaN
# Serine                                                                       NaN
# ...                                                                          ...
# PC(36:1) / PC(18:1(9Z)/18:0)                                           250732925
# SM(d18:1/24:1(15Z)) / 24:1 SM                                            3434729
# SPH(d18:1/24:0)                                                            67070
# Isovaleryl-L-Carnitine                                                     40553
# 2-Ketoglutaric Acid                                                         5680
#
# [122 rows x 401 columns]

# %%
gr1=df.iloc[1:51,0:133].copy()
gr1_meta=df.iloc[0,0:133].values
gr2=df.iloc[51:51+34,133:133+135].copy()
gr2_meta=df.iloc[0,133:133+135].values
gr3=df.iloc[85:85+37,133+135:133+135+133].copy()
gr3_meta=df.iloc[0,133+135:133+135+133].values

gr3
# Out:
#                                     20210111_LC_1 20210111_LC_10  \
# Sample ID
# Propionyl-L-carnitine                      216112         102867
# Butyryl-L-carnitine                        166185          71901
# Hexanoyl-L-carnitine                        11895           7331
# Octanoyl-L-carnitine                         2928           4529
# O-Decanoyl-L-carnitine                      56417          81647
# Lauroyl-L-carnitine                         17379          17097
# Tetradecanoylcarnitine                      23793           7196
# Palmitoil-L-Carnitine                      108593          30183
# PC(17:1(10Z)/0:0)                           45281          11351
# LysoPC(16:0)                             16378145        4900052
# LysoPC(18:1(9Z)) / LPC 18:1               4445834        2437976
# Stearoyl-L-carnitine                         3608           1688
# LysoPC(18:0)                              4182829        1254014
# LysoPC(22:0)                                20108          14225
# LysoPC(24:0)                                80027          49616
# PC(13:0/13:0)                               24777           2530
# SM(34:2)                                 14115391        5442284
# SM(d18:1/16:0)                          170901281       70493656
# PC(19:0/19:0)                               42946           9401
# SM d36:2 / C18:1 Sphingomyelin           14385727        4038110
# PC(16:1(9Z)/16:1(9Z))                     3420826        1115598
# PC(16:0/14:0)                            14989982        1664452
# 2, 3-SPPC / C18 Sphingomyelin            21419923        6899809
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)        32001713        6555977
# PC(38:6) / PDPC                         101944460       26040623
# PC(20:4/16:0) / PC(20:4n6/16:0)         247987775       54246209
# PC(16:0/18:2(9Z,12Z))                   485474819      342241178
# PC(18:0/14:0) / GPCho(18:0/14:0)         13452429        4801993
# PC(38:4)                                278145412       89505053
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)     339221578      224102272
# PC(20:0/20:0)                             1560545         490847
# PC(17:0/17:0)                             9363138        3950078
# PC(36:1) / PC(18:1(9Z)/18:0)            144373105       62720881
# SM(d18:1/24:1(15Z)) / 24:1 SM             2976738        9601425
# SPH(d18:1/24:0)                            331350         121890
# Isovaleryl-L-Carnitine                      48789          40057
# 2-Ketoglutaric Acid                          6166            955
#
#                                     20210111_LC_100 20210111_LC_101  \
# Sample ID
# Propionyl-L-carnitine                        153429          223065
# Butyryl-L-carnitine                          131535          209450
# Hexanoyl-L-carnitine                          16664           51377
# Octanoyl-L-carnitine                          18369           69252
# O-Decanoyl-L-carnitine                       140617          702971
# Lauroyl-L-carnitine                           43141          160523
# Tetradecanoylcarnitine                        27008           59066
# Palmitoil-L-Carnitine                         99418          146209
# PC(17:1(10Z)/0:0)                             82014           36308
# LysoPC(16:0)                               13327469         7780477
# LysoPC(18:1(9Z)) / LPC 18:1                 6405764         3934208
# Stearoyl-L-carnitine                           3494            5933
# LysoPC(18:0)                                4132256         2155118
# LysoPC(22:0)                                  20724            6433
# LysoPC(24:0)                                  69241           44683
# PC(13:0/13:0)                                 15298            8840
# SM(34:2)                                   15986834        11628388
# SM(d18:1/16:0)                            124056692       121729102
# PC(19:0/19:0)                                 60081           71365
# SM d36:2 / C18:1 Sphingomyelin             13199834        12638961
# PC(16:1(9Z)/16:1(9Z))                       3342443         3492412
# PC(16:0/14:0)                               9924599         8009624
# 2, 3-SPPC / C18 Sphingomyelin              17041366        23601905
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)          19406887        32754320
# PC(38:6) / PDPC                            95941356        50829599
# PC(20:4/16:0) / PC(20:4n6/16:0)           268730199       279265466
# PC(16:0/18:2(9Z,12Z))                     464179178       441742012
# PC(18:0/14:0) / GPCho(18:0/14:0)           14774698        14685831
# PC(38:4)                                  269393074       262322517
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)       335551935       288769738
# PC(20:0/20:0)                                703794          643820
# PC(17:0/17:0)                               8997400         6007940
# PC(36:1) / PC(18:1(9Z)/18:0)              104520554       105718239
# SM(d18:1/24:1(15Z)) / 24:1 SM              22454685         3706816
# SPH(d18:1/24:0)                              314852          217058
# Isovaleryl-L-Carnitine                        32874           96440
# 2-Ketoglutaric Acid                            4711            4688
#
#                                     20210111_LC_102 20210111_LC_103  \
# Sample ID
# Propionyl-L-carnitine                        511008          168437
# Butyryl-L-carnitine                          375423          206830
# Hexanoyl-L-carnitine                         115559           22226
# Octanoyl-L-carnitine                          86954           16738
# O-Decanoyl-L-carnitine                       901815          178839
# Lauroyl-L-carnitine                          284777           34705
# Tetradecanoylcarnitine                       144182           25120
# Palmitoil-L-Carnitine                        217751           93347
# PC(17:1(10Z)/0:0)                             45569           46094
# LysoPC(16:0)                               16983333        11190418
# LysoPC(18:1(9Z)) / LPC 18:1                 5444890         7312116
# Stearoyl-L-carnitine                          15134            4737
# LysoPC(18:0)                                4737286         3136256
# LysoPC(22:0)                                  15218           13592
# LysoPC(24:0)                                  53413           55647
# PC(13:0/13:0)                                  6735            8286
# SM(34:2)                                   16427137         8020852
# SM(d18:1/16:0)                            142881411        57372047
# PC(19:0/19:0)                                 89121           47309
# SM d36:2 / C18:1 Sphingomyelin             18128428         6217684
# PC(16:1(9Z)/16:1(9Z))                       3704160         1577896
# PC(16:0/14:0)                               6275602         2385863
# 2, 3-SPPC / C18 Sphingomyelin              20718359         7418029
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)          31775958         9943042
# PC(38:6) / PDPC                           150235273        82608767
# PC(20:4/16:0) / PC(20:4n6/16:0)           318493235       216885735
# PC(16:0/18:2(9Z,12Z))                     572100483       396520459
# PC(18:0/14:0) / GPCho(18:0/14:0)           13629794         7511616
# PC(38:4)                                  407408151       234090704
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)       438865688       249770990
# PC(20:0/20:0)                               1053563          906294
# PC(17:0/17:0)                              11343983         4182197
# PC(36:1) / PC(18:1(9Z)/18:0)              137131882        78353958
# SM(d18:1/24:1(15Z)) / 24:1 SM                     0        16934075
# SPH(d18:1/24:0)                                   0          335385
# Isovaleryl-L-Carnitine                        77504           41152
# 2-Ketoglutaric Acid                            7918            5264
#
#                                     20210111_LC_104 20210111_LC_106  \
# Sample ID
# Propionyl-L-carnitine                        130863          181740
# Butyryl-L-carnitine                          153008          150410
# Hexanoyl-L-carnitine                          35733           19484
# Octanoyl-L-carnitine                          41378            9948
# O-Decanoyl-L-carnitine                       345688          130588
# Lauroyl-L-carnitine                           75054           31463
# Tetradecanoylcarnitine                        52127           35717
# Palmitoil-L-Carnitine                        195743          126651
# PC(17:1(10Z)/0:0)                             82135           85937
# LysoPC(16:0)                               12894733        12134202
# LysoPC(18:1(9Z)) / LPC 18:1                 7575586         7332994
# Stearoyl-L-carnitine                          14569           10049
# LysoPC(18:0)                                4145597         3864082
# LysoPC(22:0)                                  14865           16697
# LysoPC(24:0)                                  36831           50192
# PC(13:0/13:0)                                 43696           23588
# SM(34:2)                                   14064630        13495152
# SM(d18:1/16:0)                            112588972       118352742
# PC(19:0/19:0)                                 47303          175821
# SM d36:2 / C18:1 Sphingomyelin             14008451        16808455
# PC(16:1(9Z)/16:1(9Z))                       3079712         3707293
# PC(16:0/14:0)                              13152321        22646448
# 2, 3-SPPC / C18 Sphingomyelin              20190670        28089603
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)          31751783        48593431
# PC(38:6) / PDPC                            40110970        87031063
# PC(20:4/16:0) / PC(20:4n6/16:0)           193905022       314159598
# PC(16:0/18:2(9Z,12Z))                     473561869       459195807
# PC(18:0/14:0) / GPCho(18:0/14:0)           13876851        18423591
# PC(38:4)                                  208950451       332009122
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)       361841608       358279788
# PC(20:0/20:0)                                426651          604915
# PC(17:0/17:0)                               7357313         9271984
# PC(36:1) / PC(18:1(9Z)/18:0)              185625600       202525619
# SM(d18:1/24:1(15Z)) / 24:1 SM               4588817         6049573
# SPH(d18:1/24:0)                              231498          156103
# Isovaleryl-L-Carnitine                        39374           26873
# 2-Ketoglutaric Acid                            3955            4738
#
#                                     20210111_LC_107 20210111_LC_108  ...  \
# Sample ID                                                            ...
# Propionyl-L-carnitine                        307079          301343  ...
# Butyryl-L-carnitine                          329721          168683  ...
# Hexanoyl-L-carnitine                          30154           23517  ...
# Octanoyl-L-carnitine                          23007           12356  ...
# O-Decanoyl-L-carnitine                       189344          138541  ...
# Lauroyl-L-carnitine                           81535           56029  ...
# Tetradecanoylcarnitine                        61910           41964  ...
# Palmitoil-L-Carnitine                        155771           98782  ...
# PC(17:1(10Z)/0:0)                             47445           23375  ...
# LysoPC(16:0)                                9685211         6329611  ...
# LysoPC(18:1(9Z)) / LPC 18:1                 5390170         2256629  ...
# Stearoyl-L-carnitine                           9709            2929  ...
# LysoPC(18:0)                                3003424         1665180  ...
# LysoPC(22:0)                                  13433            5759  ...
# LysoPC(24:0)                                  50303           30864  ...
# PC(13:0/13:0)                                  7146           17236  ...
# SM(34:2)                                   14230162         9916548  ...
# SM(d18:1/16:0)                            119693885        76752912  ...
# PC(19:0/19:0)                                286771           58204  ...
# SM d36:2 / C18:1 Sphingomyelin             14409734         8487006  ...
# PC(16:1(9Z)/16:1(9Z))                       2511958         1134306  ...
# PC(16:0/14:0)                               5094138         5781588  ...
# 2, 3-SPPC / C18 Sphingomyelin              18023817        12349588  ...
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)          29330839        26367397  ...
# PC(38:6) / PDPC                            69980612       101208294  ...
# PC(20:4/16:0) / PC(20:4n6/16:0)           298962457       158223025  ...
# PC(16:0/18:2(9Z,12Z))                     477295543       497104680  ...
# PC(18:0/14:0) / GPCho(18:0/14:0)           10146266         8787707  ...
# PC(38:4)                                  411576010       220357511  ...
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)       358957253       365063043  ...
# PC(20:0/20:0)                               1208674          966442  ...
# PC(17:0/17:0)                               7905221         6410468  ...
# PC(36:1) / PC(18:1(9Z)/18:0)              168822515        99333139  ...
# SM(d18:1/24:1(15Z)) / 24:1 SM              37796731               0  ...
# SPH(d18:1/24:0)                              216216          194199  ...
# Isovaleryl-L-Carnitine                       131578           77919  ...
# 2-Ketoglutaric Acid                            4102            6220  ...
#
#                                     20210111_LC_9 20210111_LC_90  \
# Sample ID
# Propionyl-L-carnitine                       83191         224614
# Butyryl-L-carnitine                         93625         618567
# Hexanoyl-L-carnitine                        11591          38763
# Octanoyl-L-carnitine                         9948          25615
# O-Decanoyl-L-carnitine                     164357         265620
# Lauroyl-L-carnitine                         41598          75603
# Tetradecanoylcarnitine                      24613          51662
# Palmitoil-L-Carnitine                       72514         154200
# PC(17:1(10Z)/0:0)                           20256         140330
# LysoPC(16:0)                              5982029       16391778
# LysoPC(18:1(9Z)) / LPC 18:1               2492275       11761579
# Stearoyl-L-carnitine                         3380           6093
# LysoPC(18:0)                              1311004        7156664
# LysoPC(22:0)                                 5340          30598
# LysoPC(24:0)                                24803          97076
# PC(13:0/13:0)                                7203         134877
# SM(34:2)                                  8823724       29198887
# SM(d18:1/16:0)                           83145560      233393345
# PC(19:0/19:0)                              188691         100902
# SM d36:2 / C18:1 Sphingomyelin            9512577       25170514
# PC(16:1(9Z)/16:1(9Z))                     2390210        4184939
# PC(16:0/14:0)                             6510720       29084848
# 2, 3-SPPC / C18 Sphingomyelin            13942455       36227460
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)        19527969       58776285
# PC(38:6) / PDPC                          84265744      217523003
# PC(20:4/16:0) / PC(20:4n6/16:0)         231560311      238155798
# PC(16:0/18:2(9Z,12Z))                   436148309      561779710
# PC(18:0/14:0) / GPCho(18:0/14:0)         11198246       19892986
# PC(38:4)                                199720192      312580021
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)     250422469      487690276
# PC(20:0/20:0)                              726552        2093163
# PC(17:0/17:0)                             4591474       13286020
# PC(36:1) / PC(18:1(9Z)/18:0)             91321505      379262938
# SM(d18:1/24:1(15Z)) / 24:1 SM             2110013       62088219
# SPH(d18:1/24:0)                            635465         370729
# Isovaleryl-L-Carnitine                          0         107550
# 2-Ketoglutaric Acid                          3094           7697
#
#                                     20210111_LC_91 20210111_LC_92  \
# Sample ID
# Propionyl-L-carnitine                       228520         105621
# Butyryl-L-carnitine                         202152         181987
# Hexanoyl-L-carnitine                         50552          43257
# Octanoyl-L-carnitine                         37170          37944
# O-Decanoyl-L-carnitine                      322452         373632
# Lauroyl-L-carnitine                         103290         109203
# Tetradecanoylcarnitine                       48988          52652
# Palmitoil-L-Carnitine                       208125         141724
# PC(17:1(10Z)/0:0)                           183600          29421
# LysoPC(16:0)                              24264604        8641852
# LysoPC(18:1(9Z)) / LPC 18:1               15295879        6405412
# Stearoyl-L-carnitine                         13889           5752
# LysoPC(18:0)                               9976200        3086510
# LysoPC(22:0)                                 35095          17595
# LysoPC(24:0)                                117589          63091
# PC(13:0/13:0)                               103905           4018
# SM(34:2)                                  39739742       11945574
# SM(d18:1/16:0)                           321224950      110345387
# PC(19:0/19:0)                               147173          25352
# SM d36:2 / C18:1 Sphingomyelin            35039149        9865478
# PC(16:1(9Z)/16:1(9Z))                      5853220        2684932
# PC(16:0/14:0)                             40862076        2891603
# 2, 3-SPPC / C18 Sphingomyelin             49339930       12882146
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)         69985894       14065213
# PC(38:6) / PDPC                          220435126       56714219
# PC(20:4/16:0) / PC(20:4n6/16:0)          308853577      218590809
# PC(16:0/18:2(9Z,12Z))                    638672533      411969143
# PC(18:0/14:0) / GPCho(18:0/14:0)          27884742       11028098
# PC(38:4)                                 347728095      282543603
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)      526049164      310918858
# PC(20:0/20:0)                              2183771        1334775
# PC(17:0/17:0)                             15979531        5855147
# PC(36:1) / PC(18:1(9Z)/18:0)             287228637      122452581
# SM(d18:1/24:1(15Z)) / 24:1 SM             65877454        2497744
# SPH(d18:1/24:0)                            1462733         215563
# Isovaleryl-L-Carnitine                       85729          27870
# 2-Ketoglutaric Acid                           6105           3973
#
#                                     20210111_LC_93 20210111_LC_94  \
# Sample ID
# Propionyl-L-carnitine                       297591         122245
# Butyryl-L-carnitine                         301475         166962
# Hexanoyl-L-carnitine                         20503           8704
# Octanoyl-L-carnitine                          8817           9941
# O-Decanoyl-L-carnitine                       83920          92377
# Lauroyl-L-carnitine                          31006          40349
# Tetradecanoylcarnitine                       28541          26208
# Palmitoil-L-Carnitine                       103509          69974
# PC(17:1(10Z)/0:0)                            22866          45644
# LysoPC(16:0)                              11212922        7474494
# LysoPC(18:1(9Z)) / LPC 18:1                2733543        4171128
# Stearoyl-L-carnitine                          4398           2365
# LysoPC(18:0)                               2686290        2209289
# LysoPC(22:0)                                 12798          12685
# LysoPC(24:0)                                 41521          37634
# PC(13:0/13:0)                                14153          64833
# SM(34:2)                                  11935063        8133411
# SM(d18:1/16:0)                            89923910       72395631
# PC(19:0/19:0)                                49925          67762
# SM d36:2 / C18:1 Sphingomyelin            11745178        7663036
# PC(16:1(9Z)/16:1(9Z))                      1994387        1482175
# PC(16:0/14:0)                              8750542        7338846
# 2, 3-SPPC / C18 Sphingomyelin             15314445       10947623
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)         39774732       16517550
# PC(38:6) / PDPC                           90731438       38319837
# PC(20:4/16:0) / PC(20:4n6/16:0)          256898756      190159707
# PC(16:0/18:2(9Z,12Z))                    503875388      430727110
# PC(18:0/14:0) / GPCho(18:0/14:0)           9872182        7948127
# PC(38:4)                                 297717991      228203100
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)      338310831      298301076
# PC(20:0/20:0)                               479821         728609
# PC(17:0/17:0)                              8309992        4930099
# PC(36:1) / PC(18:1(9Z)/18:0)             115790342       94277208
# SM(d18:1/24:1(15Z)) / 24:1 SM             36069344              0
# SPH(d18:1/24:0)                             313650         257598
# Isovaleryl-L-Carnitine                       98667          33594
# 2-Ketoglutaric Acid                           5619           1994
#
#                                     20210111_LC_95 20210111_LC_96  \
# Sample ID
# Propionyl-L-carnitine                       276020         427560
# Butyryl-L-carnitine                         411070         431711
# Hexanoyl-L-carnitine                         73556          42326
# Octanoyl-L-carnitine                         40440          14452
# O-Decanoyl-L-carnitine                      425647         225457
# Lauroyl-L-carnitine                         160885          54602
# Tetradecanoylcarnitine                      100042          50341
# Palmitoil-L-Carnitine                       175607         247744
# PC(17:1(10Z)/0:0)                           130040          75599
# LysoPC(16:0)                              14874704       20295553
# LysoPC(18:1(9Z)) / LPC 18:1               10972739        9881491
# Stearoyl-L-carnitine                          7335          12186
# LysoPC(18:0)                               5963236        4922951
# LysoPC(22:0)                                 18353          21060
# LysoPC(24:0)                                 61035          85430
# PC(13:0/13:0)                                42322          23124
# SM(34:2)                                  19835481       18382838
# SM(d18:1/16:0)                           133405634      135053735
# PC(19:0/19:0)                               128391         311838
# SM d36:2 / C18:1 Sphingomyelin            17051523       16946622
# PC(16:1(9Z)/16:1(9Z))                      2968971        3213315
# PC(16:0/14:0)                             10487108       16481841
# 2, 3-SPPC / C18 Sphingomyelin             20184310       23523733
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)         35302699       84994066
# PC(38:6) / PDPC                           84858554       94035050
# PC(20:4/16:0) / PC(20:4n6/16:0)          195307561      356874914
# PC(16:0/18:2(9Z,12Z))                    564424785      528712819
# PC(18:0/14:0) / GPCho(18:0/14:0)          12765496       15008791
# PC(38:4)                                 275800121      373694447
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)      462650568      421979227
# PC(20:0/20:0)                              1027831         450753
# PC(17:0/17:0)                              8317565       12335043
# PC(36:1) / PC(18:1(9Z)/18:0)             207340705      359063863
# SM(d18:1/24:1(15Z)) / 24:1 SM             47663483       11724618
# SPH(d18:1/24:0)                            1403869         493608
# Isovaleryl-L-Carnitine                       99391          86762
# 2-Ketoglutaric Acid                           9149           4858
#
#                                     20210111_LC_97 20210111_LC_99
# Sample ID
# Propionyl-L-carnitine                       160997         326041
# Butyryl-L-carnitine                         151352         145652
# Hexanoyl-L-carnitine                         26023          17095
# Octanoyl-L-carnitine                         12675          10276
# O-Decanoyl-L-carnitine                      146560          99608
# Lauroyl-L-carnitine                          49775          54616
# Tetradecanoylcarnitine                       49405          51745
# Palmitoil-L-Carnitine                       138246         159201
# PC(17:1(10Z)/0:0)                            91251         115535
# LysoPC(16:0)                              12771703       19616794
# LysoPC(18:1(9Z)) / LPC 18:1                9825914        9926977
# Stearoyl-L-carnitine                         10046          10275
# LysoPC(18:0)                               3341282        5020545
# LysoPC(22:0)                                  8216          20672
# LysoPC(24:0)                                 31999          86885
# PC(13:0/13:0)                                 5258          48569
# SM(34:2)                                  14297655       15030915
# SM(d18:1/16:0)                           126213692      175373043
# PC(19:0/19:0)                                52124         119279
# SM d36:2 / C18:1 Sphingomyelin            17464489       12358964
# PC(16:1(9Z)/16:1(9Z))                      4284825        1710861
# PC(16:0/14:0)                              6228391       21615496
# 2, 3-SPPC / C18 Sphingomyelin             25571709       21206680
# PC(18:1(9Z)/14:0) / PC(18:1/14:0)         27186988       57005197
# PC(38:6) / PDPC                           85895615       47381027
# PC(20:4/16:0) / PC(20:4n6/16:0)          273699386      194526974
# PC(16:0/18:2(9Z,12Z))                    419188679      546125395
# PC(18:0/14:0) / GPCho(18:0/14:0)          15496511       22521652
# PC(38:4)                                 269178334      264215680
# PC(18:0/18:2(9Z,12Z)) / GPCho(36:2)      257017453      418659600
# PC(20:0/20:0)                               983804         711308
# PC(17:0/17:0)                              6522644       13734295
# PC(36:1) / PC(18:1(9Z)/18:0)              98032980      250732925
# SM(d18:1/24:1(15Z)) / 24:1 SM              1912578        3434729
# SPH(d18:1/24:0)                              71959          67070
# Isovaleryl-L-Carnitine                       54580          40553
# 2-Ketoglutaric Acid                           4134           5680
#
# [37 rows x 133 columns]

# %%
# !pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in /opt/conda/lib/python3.10/site-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: numba>=0.51.2 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.10/site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from umap-learn) (4.66.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn) (0.43.0)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.10/site-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)

# %%
import umap
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import matplotlib.ticker as mticker

c_col=[]
for subj in gr1.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        if df_meta.loc[subj,"Condition"]=="Premenopause":
            c_col.append(0)
        else:
            c_col.append(1)
    else:
        if df_meta.loc[subj,"Condition"]=="Premenopause":
            c_col.append(2)
        else:
            c_col.append(3)

reducer = umap.UMAP(random_state=5)
scaled_data = StandardScaler().fit_transform(gr1.dropna(axis=0).T)
embedding = reducer.fit_transform(scaled_data)
plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
    c=c_col)
plt.colorbar(ticks=[0, 1, 2, 3], format=mticker.FixedFormatter(['Ctrl Pre', 'Ctrl Post', 'Depr Pre', 'Depr Post']))
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP of Group 1', fontsize=24);
# Out:
# /opt/conda/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
import umap
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import matplotlib.ticker as mticker

c_col=[]
for subj in gr2.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        if df_meta.loc[subj,"Condition"]=="Premenopause":
            c_col.append(0)
        else:
            c_col.append(1)
    else:
        if df_meta.loc[subj,"Condition"]=="Premenopause":
            c_col.append(2)
        else:
            c_col.append(3)

reducer = umap.UMAP(random_state=5)
scaled_data = StandardScaler().fit_transform(gr2.dropna(axis=0).T)
embedding = reducer.fit_transform(scaled_data)
plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
    c=c_col)
plt.colorbar(ticks=[0, 1, 2, 3], format=mticker.FixedFormatter(['Ctrl Pre', 'Ctrl Post', 'Depr Pre', 'Depr Post']))
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP of Group 2', fontsize=24);
# Out:
# /opt/conda/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
import umap
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import matplotlib.ticker as mticker

c_col=[]
for subj in gr3.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        if df_meta.loc[subj,"Condition"]=="Premenopause":
            c_col.append(0)
        else:
            c_col.append(1)
    else:
        if df_meta.loc[subj,"Condition"]=="Premenopause":
            c_col.append(2)
        else:
            c_col.append(3)

reducer = umap.UMAP(random_state=5)
scaled_data = StandardScaler().fit_transform(gr3.dropna(axis=0).T)
embedding = reducer.fit_transform(scaled_data)
plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
    c=c_col)
plt.colorbar(ticks=[0, 1, 2, 3], format=mticker.FixedFormatter(['Ctrl Pre', 'Ctrl Post', 'Depr Pre', 'Depr Post']))
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP of Group 3', fontsize=24);
# Out:
# /opt/conda/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
from sklearn import ensemble
from sklearn import tree

m='RF'

# %% [markdown]
# # Raw inputs
# ## Pre+Post together
# ### Group 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

y=[]
for subj in gr1.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):
    model=tree.DecisionTreeClassifier(max_depth=5)
else:
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr1.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.7777777777777778
# Specificity: 0.6666666666666666
# Sensitivity: 0.8333333333333334
# array([[ 6,  3],
#        [ 3, 15]])

# %% [markdown]
# ### Group 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

y=[]
for subj in gr2.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr2.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.6666666666666666
# Specificity: 0.375
# Sensitivity: 0.7894736842105263
# array([[ 3,  5],
#        [ 4, 15]])

# %% [markdown]
# ### Group 3

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

y=[]
for subj in gr3.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr3.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.8888888888888888
# Specificity: 0.6666666666666666
# Sensitivity: 1.0
# array([[ 6,  3],
#        [ 0, 18]])

# %% [markdown]
# ## Pre only
# ### Group 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Premenopause', "Subject ID"].index)
ind=list(ind.intersection(gr1.columns))
gr1_pre=gr1.loc[:,ind]

y=[]
for subj in gr1_pre.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr1_pre.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.7777777777777778
# Specificity: 0.6666666666666666
# Sensitivity: 1.0
# array([[4, 2],
#        [0, 3]])

# %% [markdown]
# ### Group 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Premenopause', "Subject ID"].index)
ind=list(ind.intersection(gr2.columns))
gr2_pre=gr2.loc[:,ind]

y=[]
for subj in gr2_pre.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr2_pre.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.6666666666666666
# Specificity: 0.5
# Sensitivity: 0.8
# array([[2, 2],
#        [1, 4]])

# %% [markdown]
# ### Group 3

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Premenopause', "Subject ID"].index)
ind=list(ind.intersection(gr3.columns))
gr3_pre=gr3.loc[:,ind]

y=[]
for subj in gr3_pre.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr3_pre.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.8888888888888888
# Specificity: 0.75
# Sensitivity: 1.0
# array([[3, 1],
#        [0, 5]])

# %% [markdown]
# ## Post only
# ### Group 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Postmenopause', "Subject ID"].index)
ind=list(ind.intersection(gr1.columns))
gr1_post=gr1.loc[:,ind]

y=[]
for subj in gr1_post.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr1_post.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.8888888888888888
# Specificity: 0.7142857142857143
# Sensitivity: 1.0
# array([[ 5,  2],
#        [ 0, 11]])

# %% [markdown]
# ### Group 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Postmenopause', "Subject ID"].index)
ind=list(ind.intersection(gr2.columns))
gr2_post=gr2.loc[:,ind]

y=[]
for subj in gr2_post.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr2_post.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.5555555555555556
# Specificity: 0.2857142857142857
# Sensitivity: 0.7272727272727273
# array([[2, 5],
#        [3, 8]])

# %% [markdown]
# ### Group 3

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Postmenopause', "Subject ID"].index)
ind=list(ind.intersection(gr3.columns))
gr3_post=gr3.loc[:,ind]

y=[]
for subj in gr3_post.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

X_train, X_test, y_train, y_test = train_test_split(
    gr3_post.dropna(axis=0).T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.8333333333333334
# Specificity: 0.6
# Sensitivity: 0.9230769230769231
# array([[ 3,  2],
#        [ 1, 12]])

# %% [markdown]
# # PCA inputs
# ## Pre+Post together
# ### Group 1

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn import tree

y = []
for subj in gr1.dropna(axis=0).columns:
    if df_meta.loc[subj, "Symptom"] == "Control":
        y.append(0)
    else:
        y.append(1)

# Initialize a list to store accuracies
accuracies = []
component_range = range(1, 40)  # Test components from 1 to 20

for n_components in component_range:
    # Apply PCA with the current number of components
    pca = PCA(n_components=n_components)
    gr1_pca = pca.fit_transform(gr1.dropna(axis=0).T)
    
    # Split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        gr1_pca, y, test_size=0.20, random_state=48)
    
    # Fit the model
    if(m=='DT'):     
        model=tree.DecisionTreeClassifier(max_depth=5) 
    else:     
        model=ensemble.RandomForestClassifier()
    model.fit(X_train, y_train)
    
    # Predict and calculate accuracy
    pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, pred)
    accuracies.append(accuracy)

# Plot accuracy vs. number of components
plt.plot(component_range, accuracies, marker='o')
plt.xlabel("Number of PCA Components")
plt.ylabel("Accuracy")
plt.title("Accuracy vs. Number of PCA Components")
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn import tree

y=[]
for subj in gr1.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(5)
pca.fit(gr1.dropna(axis=0))
gr1_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr1_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.6666666666666666
# Specificity: 0.3333333333333333
# Sensitivity: 0.8333333333333334
# array([[ 3,  6],
#        [ 3, 15]])

# %% [markdown]
# ### Group 2

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn import tree

y = []
for subj in gr2.dropna(axis=0).columns:
    if df_meta.loc[subj, "Symptom"] == "Control":
        y.append(0)
    else:
        y.append(1)

# Initialize a list to store accuracies
accuracies = []
component_range = range(1, 20)  # Test components from 1 to 20

for n_components in component_range:
    # Apply PCA with the current number of components
    pca = PCA(n_components=n_components)
    gr2_pca = pca.fit_transform(gr2.dropna(axis=0).T)
    
    # Split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        gr2_pca, y, test_size=0.20, random_state=48)
    
    # Fit the model
    if(m=='DT'):     
        model=tree.DecisionTreeClassifier(max_depth=5) 
    else:     
        model=ensemble.RandomForestClassifier()
    model.fit(X_train, y_train)
    
    # Predict and calculate accuracy
    pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, pred)
    accuracies.append(accuracy)

# Plot accuracy vs. number of components
plt.plot(component_range, accuracies, marker='o')
plt.xlabel("Number of PCA Components")
plt.ylabel("Accuracy")
plt.title("Accuracy vs. Number of PCA Components")
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn import tree

y=[]
for subj in gr2.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(5)
pca.fit(gr2.dropna(axis=0))
gr2_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr2_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.5185185185185185
# Specificity: 0.125
# Sensitivity: 0.6842105263157895
# array([[ 1,  7],
#        [ 6, 13]])

# %% [markdown]
# ### Group 3

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn import tree

y = []
for subj in gr3.dropna(axis=0).columns:
    if df_meta.loc[subj, "Symptom"] == "Control":
        y.append(0)
    else:
        y.append(1)

# Initialize a list to store accuracies
accuracies = []
component_range = range(1, 30)  # Test components from 1 to 20

for n_components in component_range:
    # Apply PCA with the current number of components
    pca = PCA(n_components=n_components)
    gr3_pca = pca.fit_transform(gr3.dropna(axis=0).T)
    
    # Split into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(
        gr3_pca, y, test_size=0.20, random_state=41)
    
    # Fit the model
    if(m=='DT'):     
        model=tree.DecisionTreeClassifier(max_depth=5) 
    else:     
        model=ensemble.RandomForestClassifier()
    model.fit(X_train, y_train)
    
    # Predict and calculate accuracy
    pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, pred)
    accuracies.append(accuracy)

# Plot accuracy vs. number of components
plt.plot(component_range, accuracies, marker='o')
plt.xlabel("Number of PCA Components")
plt.ylabel("Accuracy")
plt.title("Accuracy vs. Number of PCA Components")
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
from sklearn import tree

y=[]
for subj in gr3.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(4)
pca.fit(gr3.dropna(axis=0))
gr3_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr3_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.7407407407407407
# Specificity: 0.5555555555555556
# Sensitivity: 0.8333333333333334
# array([[ 5,  4],
#        [ 3, 15]])

# %% [markdown]
# ## Pre only
# ### Group 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Premenopause', "Subject ID"].index)
ind=list(ind.intersection(gr1.columns))
gr1_pre=gr1.loc[:,ind]

y=[]
for subj in gr1_pre.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(5)
pca.fit(gr1_pre.dropna(axis=0))
gr1_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr1_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.4444444444444444
# Specificity: 0.3333333333333333
# Sensitivity: 0.6666666666666666
# array([[2, 4],
#        [1, 2]])

# %% [markdown]
# ### Group 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Premenopause', "Subject ID"].index)
ind=list(ind.intersection(gr2.columns))
gr1_pre=gr2.loc[:,ind]

y=[]
for subj in gr2_pre.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(5)
pca.fit(gr2_pre.dropna(axis=0))
gr2_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr2_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.8888888888888888
# Specificity: 1.0
# Sensitivity: 0.8
# array([[4, 0],
#        [1, 4]])

# %% [markdown]
# ### Group 3

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Premenopause', "Subject ID"].index)
ind=list(ind.intersection(gr3.columns))
gr3_pre=gr3.loc[:,ind]

y=[]
for subj in gr3_pre.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(5)
pca.fit(gr3_pre.dropna(axis=0))
gr3_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr3_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.7777777777777778
# Specificity: 0.75
# Sensitivity: 0.8
# array([[3, 1],
#        [1, 4]])

# %% [markdown]
# ## Post only
# ### Group 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Postmenopause', "Subject ID"].index)
ind=list(ind.intersection(gr1.columns))
gr1_post=gr1.loc[:,ind]

y=[]
for subj in gr1_post.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(5)
pca.fit(gr1_post.dropna(axis=0))
gr1_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr1_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.8333333333333334
# Specificity: 0.5714285714285714
# Sensitivity: 1.0
# array([[ 4,  3],
#        [ 0, 11]])

# %% [markdown]
# ### Group 2

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Postmenopause', "Subject ID"].index)
ind=list(ind.intersection(gr2.columns))
gr2_post=gr2.loc[:,ind]

y=[]
for subj in gr2_post.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(5)
pca.fit(gr2_post.dropna(axis=0))
gr2_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr2_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.5555555555555556
# Specificity: 0.2857142857142857
# Sensitivity: 0.7272727272727273
# array([[2, 5],
#        [3, 8]])

# %% [markdown]
# ### Group 3

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import tree

ind=set(df_meta.loc[df_meta["Condition"]=='Postmenopause', "Subject ID"].index)
ind=list(ind.intersection(gr3.columns))
gr3_post=gr3.loc[:,ind]

y=[]
for subj in gr3_post.dropna(axis=0).columns:
    if df_meta.loc[subj,"Symptom"]=="Control":
        y.append(0)
    else:
        y.append(1)

if(m=='DT'):     
    model=tree.DecisionTreeClassifier(max_depth=5) 
else:     
    model=ensemble.RandomForestClassifier()

pca=PCA(5)
pca.fit(gr3_post.dropna(axis=0))
gr3_pca=pca.components_

X_train, X_test, y_train, y_test = train_test_split(
    gr3_pca.T, y, test_size=0.20, random_state=43)
fitted=model.fit(X_train, y_train)
pred=fitted.predict(X_test)
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
specificity = tn / (tn+fp)
sensitivity= tp/(tp+fn)
print("Accuracy: "+str(accuracy_score(y_test, pred)))
print("Specificity: "+str(specificity))
print("Sensitivity: "+str(sensitivity))
confusion_matrix(y_test, pred, labels=[0,1])
# Out:
# Accuracy: 0.7222222222222222
# Specificity: 0.4
# Sensitivity: 0.8461538461538461
# array([[ 2,  3],
#        [ 2, 11]])

# %%
from sklearn.tree import _tree

def tree_to_code(tree, feature_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    print ("def tree({}):".format(", ".join(feature_names)))

    def recurse(node, depth):
        indent = "  " * depth
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            print ("{}if {} <= {}:".format(indent, name, threshold))
            recurse(tree_.children_left[node], depth + 1)
            print ("{}else:  # if {} > {}".format(indent, name, threshold))
            recurse(tree_.children_right[node], depth + 1)
        else:
            print ("{}return {}".format(indent, np.argmax(tree_.value[node])))

    recurse(0, 1)
